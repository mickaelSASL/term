# %% [markdown]
# # Comment représenter les frontières entre ces pays ?
# <img src="data:image/png;base64,..." style="display: inline;
# 	float: left;
# 	margin: auto;">

# %% [markdown]
# # Vous venez de créer un graphe !
# <img src="data:image/png;base64,..." style="display: inline;
# 	float: left;
# 	margin: auto;">
# <img src="data:image/png;base64,..." tyle="display: inline;
# 	float: left;
# 	margin: auto;">

# %% [markdown]
# # Autre exemple : un réseau social
# Considérons un mini réseau qui contient 8 personnes (pour plus de simplicité !) :
# *Alban, Béatrice, Charles, Déborah, Éric, Fatima, Gérald et Hélène.*
# Voici les **relations** d’amitié qui lient ces membre du réseau :
#
# - Alban est ami avec Béatrice, Déborah, Éric et Fatima.
# - Béatrice est amie avec Alban, Charles, Déborah, Éric et Gérald.
# - Charles est ami avec Béatrice, Déborah et Hélène.
# - Déborah est amie avec Alban, Béatrice, Charles et Gérald.
# - Éric est ami avec Alban et Béatrice.
# - Fatima est amie avec Alban, Gérald et Hélène.
# - Gérald est ami avec Béatrice, Déborah, Fatima et Hélène.
# - Hélène est amie avec Charles, Gérald et Fatima.
#
# Cette énumération dans laquelle on fait la liste des relations, individus par individus s'appelle liste **d'adjacence**.

# %% [markdown]
# <img style="display: inline; float: left; margin: auto;" src="data:image/png;base64,...">
# <table>
#     <tr><td>A</td> <td>Alban</td></tr>
#     <tr><td>B</td> <td>Béatrice</td></tr>
#     <tr><td>C</td> <td>Charles</td></tr>
#     <tr><td>D</td> <td>Déborah</td></tr>
#     <tr><td>E</td> <td>Eric</td></tr>
#     <tr><td>F</td> <td>Fatima</td></tr>
#     <tr><td>G</td> <td>Gérald</td></tr>
#     <tr><td>H</td> <td>Hélène</td></tr>
# </table>

# %% [markdown]
# <img style="display: inline; float: left; margin: auto;" src="data:image/png;base64,...">
#
# <br><table style="display: inline; float: left; margin-left: 50px;" >
#     <tr><td>A</td> <td>Alban</td></tr>
#     <tr><td>B</td> <td>Béatrice</td></tr>
#     <tr><td>C</td> <td>Charles</td></tr>
#     <tr><td>D</td> <td>Déborah</td></tr>
#     <tr><td>E</td> <td>Eric</td></tr>
#     <tr><td>F</td> <td>Fatima</td></tr>
#     <tr><td>G</td> <td>Gérald</td></tr>
#     <tr><td>H</td> <td>Hélène</td></tr>
# </table>
#
# <div style="display: inline; float: right; margin-right: 15px; font-weight: bold;">  Matrice d'adjacence <br><br>
# <table style="display: inline; float: right; margin: auto;" >
#     <tr style="font-weight: bold;">
#         <td></td><td>A</td> <td>B</td> <td>C</td> <td>D</td> <td>E</td> <td>F</td> <td>G</td> <td>H</td></tr>
#     <tr><td style="font-weight: bold;">A</td>
#         <td>0</td> <td>1</td> <td>0</td> <td>1</td> <td>1</td> <td>1</td> <td>0</td> <td>0</td></tr>
#     <tr><td style="font-weight: bold;">B</td>
#         <td>1</td> <td>0</td> <td>1</td> <td>1</td> <td>1</td> <td>0</td> <td>1</td> <td>0</td></tr>
#     <tr><td style="font-weight: bold;">C</td>
#         <td>0</td> <td>1</td> <td>0</td> <td>1</td> <td>0</td> <td>0</td> <td>0</td> <td>1</td></tr>
#     <tr><td style="font-weight: bold;">D</td>
#         <td>1</td> <td>1</td> <td>1</td> <td>0</td> <td>0</td> <td>0</td> <td>1</td> <td>0</td></tr>
#     <tr><td style="font-weight: bold;">E</td>
#         <td>1</td> <td>1</td> <td>0</td> <td>0</td> <td>0</td> <td>0</td> <td>0</td> <td>0</td></tr>
#     <tr><td style="font-weight: bold;">F</td>
#         <td>1</td> <td>0</td> <td>0</td> <td>0</td> <td>0</td> <td>0</td> <td>1</td> <td>1</td></tr>
#     <tr><td style="font-weight: bold;">G</td>
#         <td>0</td> <td>1</td> <td>0</td> <td>1</td> <td>0</td> <td>1</td> <td>0</td> <td>1</td></tr>
#     <tr><td style="font-weight: bold;">H</td>
#         <td>0</td> <td>0</td> <td>1</td> <td>0</td> <td>0</td> <td>1</td> <td>1</td> <td>0</td></tr>
# </table>
#     </div>
