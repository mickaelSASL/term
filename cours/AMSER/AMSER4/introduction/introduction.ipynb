# %% [markdown]
# <br><br><br>
#
# <center> <div style="font-size:72px"> tm kwliom lm kmaiz </div>
#
# <br><br><br>

# %% [markdown]
# <br><br><br>
#
# <center>
#     <div style="font-size:72px"> le codage de César </div>
#
#
# <br><br>   <center>  avec une clé de 8<br>

# %% [markdown]
# # Sécurisation des communications
# ## Codage de César

# %% [markdown]
# ![image.png](image.png)
